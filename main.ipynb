# %%
# Test

# %%
from nucleotide import reverse_complement

# %%
reverse_complement('dataset.txt')
# Out:
# '...'

# %%
import re


pattern = "ATAT"

geneome = "GATATATGCATATACTT"

matches = re.finditer(pattern, geneome)

[match.start() for match in matches]
# Out:
# [1, 9]
